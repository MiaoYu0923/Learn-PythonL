# %%
#to defile a function to identify whether it is even or odd
def even_or_odd(num):
        if num % 2 == 0:
            print("This is an even number.")
        else:
            print("This is an odd number.")
def main():
    #to do the "even or odd checker"
    print("Even or Odd Checker")
    print()
    #type a number first
    num = int(input("Please enter a integer"))
    print("Enter an integer:" + str(num))
    even_or_odd(num)
if __name__ == '__main__':
    main()
# Out:
# Even or Odd Checker
#
# Enter an integer:33
# This is an odd number.
